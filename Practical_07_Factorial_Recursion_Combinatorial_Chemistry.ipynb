# %% [markdown]
# # Practical 7: Factorial Calculation using Recursion
#
# ### Computer Programming Lab – Chemical Engineering
# **Syllabus Experiment:** **Factorial calculation using recursion applied to combinatorial chemistry problems**
# **Environment:** GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: Exact Syllabus Context
#
# The complete experiment line in the syllabus is:
#
# > **Factorial calculation using recursion applied to combinatorial chemistry problems**
#
# This practical therefore has two connected parts:
#
# 1. Learn and implement **factorial calculation using recursion**.
# 2. Apply factorials to a simple **combinatorial chemistry** problem.
#
# ## How we will use AI Copilot
#
# GitHub Copilot is your AI coding assistant. Use it to understand recursion, identify base cases, debug errors and connect factorials with combinations.
#
# **Do not ask Copilot to write the complete practical at the beginning.** First understand the mathematical logic and write the basic function yourself.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Understand the factorial of a non-negative integer.
# 2. Write a recursive factorial function in Python.
# 3. Identify the base case and recursive case.
# 4. Trace recursive function calls.
# 5. Validate factorial input.
# 6. Use factorials to calculate combinations.
# 7. Apply combinations to a simple combinatorial chemistry example.
# 8. Understand why mathematical results must still be interpreted in the context of the problem.
# 9. Use GitHub Copilot to explain and debug recursive programs.

# %% [markdown]
# ## 2. What is a Factorial?
#
# For a non-negative integer `n`, factorial is written as `n!`.
#
# For example:
#
# ```text
# 5! = 5 × 4 × 3 × 2 × 1 = 120
# ```
#
# The recursive definition is:
#
# ```text
# 0! = 1
# n! = n × (n-1)!    for n > 0
# ```
#
# genui{"functions_sequences_graphs_without_graphable_function_learning_block":{"type_id":"ARITHMETIC_SEQUENCE_SUM_FORMULA","locale_override":"en-IN"}}
#
# **Note:** The visualization above is a warm-up for the idea of repeated multiplication and is not the factorial formula itself. The important programming definition for this practical is the recursive relationship given above.

# %% [markdown]
# ## 3. Activity 1 – Calculate Factorials Manually
#
# Calculate the following without Python:
#
# ```text
# 0! = ?
# 1! = ?
# 3! = ?
# 4! = ?
# 5! = ?
# ```
#
# ### Think before coding
#
# Why is `0!` defined as `1`?
#
# Why is a special stopping condition necessary when factorial is implemented recursively?

# %% [markdown]
# ### Copilot Activity 1 – Understand the Recursive Definition
#
# Ask Copilot:
#
# > Explain factorial recursively to a second-year engineering student. Clearly identify the base case and recursive case. Use 5! as an example, but do not write the complete Python function.

# %%
# Activity 1
# Verify the small factorial values using simple Python expressions.

factorial_0 = 1  # 0! = 1
factorial_1 = 1  # 1! = 1
factorial_2 = 1 * 2  # 2! = 2
factorial_3 = 1 * 2 * 3  # 3! = 6
factorial_4 = 1 * 2 * 3 * 4

print("Factorial of 0:", factorial_0)
print("Factorial of 1:", factorial_1)           
print("Factorial of 2:", factorial_2)
print("Factorial of 3:", factorial_3)
print("Factorial of 4:", factorial_4)
# Out:
# Factorial of 0: 1
# Factorial of 1: 1
# Factorial of 2: 2
# Factorial of 3: 6
# Factorial of 4: 24

# %% [markdown]
# ## 4. Activity 2 – Recursive Factorial Function
#
# Create a Python function:
#
# ```text
# factorial(n)
# ```
#
# The function should:
#
# 1. Check the base case.
# 2. Return `1` for `n = 0`.
# 3. Otherwise return `n * factorial(n-1)`.
#
# Test it with `0`, `1`, `3`, `5` and `7`.

# %% [markdown]
# ### Copilot Activity 2 – Write the Recursive Logic
#
# Ask Copilot:
#
# > I need to implement factorial recursively in Python. Explain how the function call factorial(n-1) eventually reaches the base case. Do not give me the complete code.

# %%
# Activity 2
# Write your recursive factorial function here.

def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

# %%
factorial(5)  # Example usage of the recursive factorial function
# Out:
# 120

# %% [markdown]
# ## 5. Activity 3 – Trace the Recursive Calls
#
# For `factorial(4)`, trace the calls manually:
#
# ```text
# factorial(4)
#     ↓
# factorial(3)
#     ↓
# factorial(2)
#     ↓
# factorial(1)
#     ↓
# factorial(0)
# ```
#
# Then trace the return values back upward.
#
# Complete:
#
# ```text
# factorial(0) = ___
# factorial(1) = ___
# factorial(2) = ___
# factorial(3) = ___
# factorial(4) = ___
# ```

# %% [markdown]
# ### Copilot Activity 3 – Recursion Trace
#
# Ask Copilot:
#
# > Trace factorial(4) step by step, showing both the downward recursive calls and the upward return values. Explain it as if teaching a beginner. Do not provide additional code.

# %%
# Activity 3
# Use your factorial function to verify factorial(4).

def factorial_trace(n):
    if n == 0 or n == 1:
        print(f"factorial({n}) = 1")
        return 1
    else:
        result = n * factorial_trace(n - 1)
        print(f"factorial({n}) = {result}")
        return result

# %%
factorial_trace(4)  # Example usage of the recursive factorial function with tracing
# Out:
# factorial(1) = 1
# factorial(2) = 2
# factorial(3) = 6
# factorial(4) = 24
# 24

# %% [markdown]
# ## 6. Activity 4 – Input Validation
#
# Modify your program so that the user enters `n`.
#
# Factorial is normally defined here only for **non-negative integers**.
#
# Test:
#
# - `5` → valid
# - `0` → valid
# - `-3` → invalid
# - `4.5` → invalid
# - `abc` → invalid
#
# Your program should display a useful message instead of crashing.

# %% [markdown]
# ### Copilot Activity 4 – Validation
#
# Ask Copilot:
#
# > Explain how I should validate user input for a recursive factorial function when n must be a non-negative integer. Include text input, decimal input and negative input. Do not write the complete program.

# %%
# Activity 4
# Add input validation to your factorial program.

# %% [markdown]
# ## 7. Activity 5 – Factorial and Combinations
#
# Factorials are useful in combinatorics.
#
# The number of ways of selecting `r` objects from `n` objects, when order does not matter, is:
#
# ```text
# C(n, r) = n! / (r! (n-r)!)
# ```
#
# These combinations are useful when discussing possible selections of molecules, components, samples or experimental choices.
#
# For example, if 5 different chemical components are available and we select 2 of them, the number of possible selections is:
#
# ```text
# C(5, 2)
# ```

# %% [markdown]
# ### Copilot Activity 5 – Understand Combinations
#
# Ask Copilot:
#
# > Explain the combination formula C(n,r) = n!/(r!(n-r)!) to a second-year chemical engineering student. Explain why factorial appears in the formula. Do not write Python code.

# %%
# Activity 5
# Use your recursive factorial function to calculate C(5, 2).

def combination(n, r):
    if r > n:
        return 0
    return factorial(n) // (factorial(r) * factorial(n - r))

# %%
combination_result = combination(5, 2)
print("C(5, 2) =", combination_result)
# Out:
# C(5, 2) = 10

# %% [markdown]
# ## 8. Activity 6 – Combinatorial Chemistry Example
#
# Consider a simplified formulation-screening exercise.
#
# A laboratory has **6 different candidate chemical components** available for a teaching experiment. A formulation is to be prepared by selecting **3 different components**, where the order of selection does not matter.
#
# Calculate the number of possible combinations.
#
# Use:
#
# ```text
# C(6, 3) = 6! / (3! × 3!)
# ```
#
# ### Engineering interpretation
#
# The result tells us how many different **sets of 3 components** can be selected from the 6 candidates, assuming that:
#
# - each component can be selected at most once,
# - order does not matter,
# - every combination is considered separately.
#
# This is a simplified combinatorial example, not a statement about actual formulation feasibility.

# %% [markdown]
# ### Copilot Activity 6 – Chemical Combinations
#
# Ask Copilot:
#
# > Explain how combinations can be used in a chemical formulation screening problem where we select 3 components from 6 candidates and order does not matter. Explain the meaning of the result without solving it for me.

# %%
# Activity 6
# Calculate the number of ways to select 3 components from 6 using your factorial function.

# %% [markdown]
# ## 9. Activity 7 – Build a General Combination Function
#
# Create a function:
#
# ```text
# combination(n, r)
# ```
#
# It should:
#
# 1. Validate `n` and `r`.
# 2. Ensure `n ≥ 0`.
# 3. Ensure `r ≥ 0`.
# 4. Ensure `r ≤ n`.
# 5. Use your **recursive factorial function**.
# 6. Return the number of combinations.
#
# Test:
#
# ```text
# C(5,2)
# C(6,3)
# C(10,2)
# C(10,5)
# ```

# %% [markdown]
# ### Copilot Activity 7 – Function Design
#
# Ask Copilot:
#
# > Help me design a beginner Python combination(n,r) function that uses my recursive factorial function. Explain the validation conditions r <= n and r >= 0. Do not write the complete solution.

# %%
# Activity 7
# Build your general combination function using recursive factorial.

# %% [markdown]
# ## 10. Activity 8 – Experimental Selection Problem
#
# Suppose a laboratory has **8 candidate chemicals** for a preliminary screening study and wants to select **3 chemicals at a time** for a hypothetical combination study.
#
# Write a program that calculates:
#
# ```text
# C(8, 3)
# ```
#
# Then modify it so that the user can enter `n` and `r`.
#
# ### Important distinction
#
# `C(n,r)` counts **selections where order does not matter**.
#
# If the order of the selected components mattered, a different calculation would be required.

# %%
# Activity 8
# Calculate C(8,3), then make n and r user inputs.

# %% [markdown]
# ## 11. Copilot Debugging Challenge
#
# The following recursive function contains a common error.
#
# Study it **before** asking Copilot.
#
# ```python
# def factorial(n):
#     if n == 1:
#         return 1
#     return n * factorial(n - 1)
# ```
#
# ### Your task
#
# 1. Run `factorial(5)`.
# 2. Then run `factorial(0)`.
# 3. Observe what happens.
# 4. Identify why the function does not correctly handle `0!`.
# 5. Ask Copilot:
#
# > My recursive factorial function works for positive values but fails for factorial(0). Explain which base case is missing and why 0! must return 1. Do not rewrite the complete function.
#
# 6. Correct the function yourself.

# %%
# Run the intentionally incomplete factorial function here.
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n - 1)

print('5! =', factorial(5))
print('0! =', factorial(0))

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 12. Testing
#
# ### Factorial tests
#
# | Test | n | Expected result |
# |---|---:|---:|
# | 1 | 0 | 1 |
# | 2 | 1 | 1 |
# | 3 | 5 | 120 |
# | 4 | 7 | 5040 |
# | 5 | 10 | 3628800 |
# | 6 | -2 | Invalid |
#
# ### Combination tests
#
# | Test | n | r | Expected result |
# |---|---:|---:|---:|
# | 1 | 5 | 2 | 10 |
# | 2 | 6 | 3 | 20 |
# | 3 | 8 | 3 | 56 |
# | 4 | 10 | 5 | 252 |
# | 5 | 5 | 7 | Invalid |
# | 6 | 5 | -1 | Invalid |

# %% [markdown]
# ## 13. Final Mini-Project – Combinatorial Chemistry Calculator
#
# Build one clean Python program containing:
#
# ### Function 1 – Recursive Factorial
# `factorial(n)`
#
# ### Function 2 – Combination
# `combination(n, r)`
#
# ### Program requirements
#
# 1. Ask the user whether they want to calculate a factorial or a combination.
# 2. For factorial, accept a non-negative integer `n`.
# 3. For combination, accept `n` and `r`.
# 4. Validate all inputs.
# 5. Use the **recursive factorial function** for the combination calculation.
# 6. Display the result clearly.
# 7. For a combination, explain that the result represents the number of possible selections when order does not matter.
# 8. Include a simple chemical-screening example in the output or demonstration.
#
# Example application:
#
# ```text
# Number of candidate chemicals = 8
# Number selected for a trial = 3
# Number of possible selections = 56
# ```

# %%
# FINAL PROGRAM
# Combinatorial Chemistry Calculator
# Implement recursive factorial and combination functions.

# %% [markdown]
# ## 14. Optional Challenge – Iterative vs Recursive Factorial
#
# The syllabus specifically requires **recursion**, so the recursive implementation is compulsory.
#
# As an optional extension, write an iterative factorial function and compare it with the recursive version.
#
# Ask Copilot:
#
# > Compare iterative and recursive factorial implementations in Python. Explain the advantages and limitations of recursion for this problem. Do not rewrite my practical.

# %% [markdown]
# ## 15. Final Copilot Review
#
# After completing your final program, ask Copilot:
#
# > Review my Python program for recursive factorial and combinatorial chemistry calculations. Check the base case, recursive case, input validation, combination formula and physical/contextual interpretation. Do not rewrite my program; identify possible issues and explain them.
#
# Make changes only after you understand the feedback.

# %% [markdown]
# ## 16. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. What is factorial?
# 2. What is the base case of the recursive factorial function?
# 3. Why is `0! = 1` important in the program?
# 4. What is recursion?
# 5. How does `factorial(n-1)` eventually stop?
# 6. How are factorials used in the combination formula?
# 7. What does `C(n,r)` represent when order does not matter?
# 8. How can combinations be useful in a chemical formulation or screening exercise?
# 9. What error did you find in the debugging challenge?
# 10. What did Copilot help you understand or debug?
# 11. Can you explain your recursive function without opening Copilot?

# %% [markdown]
# ## 17. Submission Checklist
#
# - [ ] I understand factorial calculation.
# - [ ] I implemented factorial using recursion.
# - [ ] I correctly used the base case `0! = 1`.
# - [ ] I traced recursive calls.
# - [ ] I added input validation.
# - [ ] I implemented combinations using factorials.
# - [ ] I applied combinations to a chemical-screening example.
# - [ ] I completed the debugging challenge.
# - [ ] I tested valid and invalid inputs.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain my final program.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 18. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Correct factorial concept and calculations | 1 |
# | Recursive factorial implementation | 3 |
# | Base case and recursion explanation | 1 |
# | Combination calculation using factorial | 2 |
# | Combinatorial chemistry application | 1 |
# | Validation, testing and debugging | 1 |
# | Copilot usage and explanation | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, give a new `n` and ask the student to trace the recursive calls. Then give a new `n, r` pair and ask what `C(n,r)` means in the context of selecting chemical components. Ask specifically why the factorial base case must include `0`.
